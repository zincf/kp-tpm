# %%
import pandas as pd

# %%
mtx_122612 = pd.read_csv('/Users/zincf/PycharmProjects/IDO-Chemokine/data_concatenation/datasets/GSE122612/GSE122612_series_matrix.csv')

# %%
mtx_122612
# Out:
#                             !Sample_title  \
# 0                   !Sample_geo_accession
# 1                          !Sample_status
# 2                 !Sample_submission_date
# 3                !Sample_last_update_date
# 4                            !Sample_type
# 5                   !Sample_channel_count
# 6                 !Sample_source_name_ch1
# 7                    !Sample_organism_ch1
# 8             !Sample_characteristics_ch1
# 9   !Sample_characteristics_ch1-cell_type
# 10            !Sample_characteristics_ch1
# 11            !Sample_characteristics_ch1
# 12   !Sample_characteristics_ch1-response
# 13            !Sample_characteristics_ch1
# 14                   !Sample_molecule_ch1
# 15           !Sample_extract_protocol_ch1
# 16           !Sample_extract_protocol_ch1
# 17                      !Sample_taxid_ch1
# 18                !Sample_data_processing
# 19                !Sample_data_processing
# 20                !Sample_data_processing
# ...
